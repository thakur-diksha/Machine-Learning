# %% [markdown]
# #Extreme Gradient Boosting - xgboost
# ####extreme gradiant boost= classfication as well as regression
# - used with big data
# - tree in parallel, fast and accuracy

# %%
pip install xgboost

# %%
import xgboost as xgb
from xgboost import XGBClassifier

# %%
model= XGBClassifier()

# %%
from sklearn.datasets import load_iris

# %%
data=load_iris()
x,y=load_iris(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.30, random_state=7)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (105, 4) (105,)
# (45, 4) (45,)

# %%
model.fit(x_train,y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
predictions=model.predict(x_test)

# %%
from sklearn.metrics import classification_report 
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       0.88      0.88      0.88        16
#            2       0.88      0.88      0.88        17
#
#     accuracy                           0.91        45
#    macro avg       0.92      0.92      0.92        45
# weighted avg       0.91      0.91      0.91        45

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy= accuracy_score(y_test,predictions)
print("Accuracy score %.2f%%"%(accuracy*100))
# Out:
# Accuracy score 91.11%

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,predictions))
# Out:
# [[12  0  0]
#  [ 0 14  2]
#  [ 0  2 15]]

# %%
label=data['target_names']
label
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cm=metrics.confusion_matrix(y_test,predictions)
plt.figure(figsize=(7,7))
ax=sns.heatmap(cm,xticklabels=label,yticklabels=label, annot=True)
plt.title("Confusion Matrix")
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %% [markdown]
# ###cross-validation score

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(model,x_test,y_test,cv=5)
score
# Out:
# array([0.88888889, 0.66666667, 0.88888889, 1.        , 1.        ])
